# %%
import pandas as pd
all = pd.read_csv("IPL_Auction_2026 - All-rounders.csv")

all
# Out:
#                    Name   Runs  Strike rate  batting avg  wickets  economy  \
# 0       Andrew McDonald   47.0       134.28        23.50      5.0     6.10
# 1           Chris Gayle  733.0       160.74        61.08      0.0     0.00
# 2      Moises Henriques    0.0         0.00         0.00      0.0     0.00
# 3        Kieron Pollard  220.0       138.36        24.44     16.0     7.98
# 4          Dwayne Smith  157.0       160.20        39.25      2.0     7.30
# 5       Harbhajan Singh  108.0       135.00        12.00      6.0     7.11
# 6          Rishi Dhawan    0.0         0.00         0.00      0.0     0.00
# 7        Axar patel (-)    0.0         0.00         0.00      0.0     0.00
# 8      Mitchell Johnson    0.0         0.00         0.00      0.0     0.00
# 9          Dwyane Bravo  371.0       140.53        46.37     15.0     7.99
# 10      Ravindra Jadeja  191.0       126.49        15.91     12.0     7.80
# ...
